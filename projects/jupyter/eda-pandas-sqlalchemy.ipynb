# %% [markdown]
# # EDA with Pandas & sqlalchemy
# How to query a database and perform edas with pandas + sql.

# %%
# !pip install sqlalchemy psycopg2-binary Pandas

# %%
from sqlalchemy.engine.url import URL
from sqlalchemy import create_engine, MetaData, Table, dialects
import pandas as pd
postgres_db = {'drivername': 'postgresql',
               'username': 'postgres',
               'password': 'postgres',
               'host': '172.17.0.1', # alternatively, 127.0.0.1/localhost if running standalone
               'port': 5432,
               'database': 'postgres'
               }
pgURL = URL(**postgres_db)
engine = create_engine(pgURL)
conn = engine.connect()
# Out:
# /tmp/ipykernel_135/1390914322.py:11: SADeprecationWarning: Calling URL() directly is deprecated and will be disabled in a future release.  The public constructor for URL is now the URL.create() method.
#   pgURL = URL(**postgres_db)

# %%
query = """
SELECT * FROM information_schema.tables
"""
df = pd.read_sql(query, conn)
df
# Out:
#     table_catalog        table_schema            table_name  table_type  \
# 0        postgres          pg_catalog          pg_statistic  BASE TABLE
# 1        postgres          pg_catalog               pg_type  BASE TABLE
# 2        postgres          pg_catalog      pg_foreign_table  BASE TABLE
# 3        postgres          pg_catalog             pg_authid  BASE TABLE
# 4        postgres          pg_catalog             pg_shadow        VIEW
# ..            ...                 ...                   ...         ...
# 198      postgres  information_schema       foreign_servers        VIEW
# 199      postgres  information_schema    _pg_foreign_tables        VIEW
# 200      postgres  information_schema  user_mapping_options        VIEW
# 201      postgres  information_schema        foreign_tables        VIEW
# 202      postgres  information_schema     _pg_user_mappings        VIEW
#
#     self_referencing_column_name reference_generation  \
# ...

# %%
query = """
SELECT * FROM information_schema.tables
WHERE table_schema = 'pg_catalog'
"""
df_2 = pd.read_sql(query, conn)
df_2
# Out:
#     table_catalog table_schema                  table_name  table_type  \
# 0        postgres   pg_catalog                pg_statistic  BASE TABLE
# 1        postgres   pg_catalog                     pg_type  BASE TABLE
# 2        postgres   pg_catalog            pg_foreign_table  BASE TABLE
# 3        postgres   pg_catalog                   pg_authid  BASE TABLE
# 4        postgres   pg_catalog                   pg_shadow        VIEW
# ..            ...          ...                         ...         ...
# 129      postgres   pg_catalog            pg_stat_database        VIEW
# 130      postgres   pg_catalog  pg_stat_database_conflicts        VIEW
# 131      postgres   pg_catalog      pg_stat_user_functions        VIEW
# 132      postgres   pg_catalog            pg_user_mappings        VIEW
# 133      postgres   pg_catalog              pg_largeobject  BASE TABLE
#
#     self_referencing_column_name reference_generation  \
# 0                           None                 None
# ...

# %%
conn.close()
